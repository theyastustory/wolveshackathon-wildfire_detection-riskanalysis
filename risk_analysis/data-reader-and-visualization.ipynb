# %% [markdown]
# # Imports

# %% [markdown]
# Import the required libraries.

# %%
import os
import re
from typing import Dict, List, Optional, Text, Tuple
import matplotlib.pyplot as plt
from matplotlib import colors

import tensorflow as tf

# %% [markdown]
# # Load the dataset

# %% [markdown]
# Enter the Unix glob file pattern of the data files.
#
# Here we load the training data. All the data are stored in TensorFlow Record files.
# Replace 'train' with 'eval' or 'test' to load the evaluation or testing data, respectively.

# %%
file_pattern = '/kaggle/input/next-day-wildfire-spread/next_day_wildfire_spread_train*'

# %% [markdown]
# Run the following three cells to define the required library functions for loading the data.
#
# The first cell defines the name of the variables in the input files and the corrresponding data statistics. The statistics can be used for preprocessing the data.

# %%
"""Constants for the data reader."""

INPUT_FEATURES = ['elevation', 'th', 'vs',  'tmmn', 'tmmx', 'sph', 
                  'pr', 'pdsi', 'NDVI', 'population', 'erc', 'PrevFireMask']

OUTPUT_FEATURES = ['FireMask', ]

# Data statistics 
# For each variable, the statistics are ordered in the form:
# (min_clip, max_clip, mean, standard deviation)
DATA_STATS = {
    # Elevation in m.
    # 0.1 percentile, 99.9 percentile
    'elevation': (0.0, 3141.0, 657.3003, 649.0147),
    # Pressure
    # 0.1 percentile, 99.9 percentile
    'pdsi': (-6.12974870967865, 7.876040384292651, -0.0052714925, 2.6823447),
    'NDVI': (-9821.0, 9996.0, 5157.625, 2466.6677),  # min, max
    # Precipitation in mm.
    # Negative values do not make sense, so min is set to 0.
    # 0., 99.9 percentile
    'pr': (0.0, 44.53038024902344, 1.7398051, 4.482833),
    # Specific humidity.
    # Negative values do not make sense, so min is set to 0.
    # The range of specific humidity is up to 100% so max is 1.
    'sph': (0., 1., 0.0071658953, 0.0042835088),
    # Wind direction in degrees clockwise from north.
    # Thus min set to 0 and max set to 360.
    'th': (0., 360.0, 190.32976, 72.59854),
    # Min/max temperature in Kelvin.
    # -20 degree C, 99.9 percentile
    'tmmn': (253.15, 298.94891357421875, 281.08768, 8.982386),
    # -20 degree C, 99.9 percentile
    'tmmx': (253.15, 315.09228515625, 295.17383, 9.815496),
    # Wind speed in m/s.
    # Negative values do not make sense, given there is a wind direction.
    # 0., 99.9 percentile
    'vs': (0.0, 10.024310074806237, 3.8500874, 1.4109988),
    # NFDRS fire danger index energy release component expressed in BTU's per
    # square foot.
    # Negative values do not make sense. Thus min set to zero.
    # 0., 99.9 percentile
    'erc': (0.0, 106.24891662597656, 37.326267, 20.846027),
    # Population density
    # min, 99.9 percentile
    'population': (0., 2534.06298828125, 25.531384, 154.72331),
    # We don't want to normalize the FireMasks.
    # 1 indicates fire, 0 no fire, -1 unlabeled data
    'PrevFireMask': (-1., 1., 0., 1.),
    'FireMask': (-1., 1., 0., 1.)
}

# %% [markdown]
# The following cell defines cropping functions for extracting regions of the desired size from the input data.

# %%
"""Library of common functions used in deep learning neural networks.
"""
def random_crop_input_and_output_images(
    input_img: tf.Tensor,
    output_img: tf.Tensor,
    sample_size: int,
    num_in_channels: int,
    num_out_channels: int,
) -> Tuple[tf.Tensor, tf.Tensor]:
  """Randomly axis-align crop input and output image tensors.

  Args:
    input_img: tensor with dimensions HWC.
    output_img: tensor with dimensions HWC.
    sample_size: side length (square) to crop to.
    num_in_channels: number of channels in input_img.
    num_out_channels: number of channels in output_img.
  Returns:
    input_img: tensor with dimensions HWC.
    output_img: tensor with dimensions HWC.
  """
  combined = tf.concat([input_img, output_img], axis=2)
  combined = tf.image.random_crop(
      combined,
      [sample_size, sample_size, num_in_channels + num_out_channels])
  input_img = combined[:, :, 0:num_in_channels]
  output_img = combined[:, :, -num_out_channels:]
  return input_img, output_img


def center_crop_input_and_output_images(
    input_img: tf.Tensor,
    output_img: tf.Tensor,
    sample_size: int,
) -> Tuple[tf.Tensor, tf.Tensor]:
  """Center crops input and output image tensors.

  Args:
    input_img: tensor with dimensions HWC.
    output_img: tensor with dimensions HWC.
    sample_size: side length (square) to crop to.
  Returns:
    input_img: tensor with dimensions HWC.
    output_img: tensor with dimensions HWC.
  """
  central_fraction = sample_size / input_img.shape[0]
  input_img = tf.image.central_crop(input_img, central_fraction)
  output_img = tf.image.central_crop(output_img, central_fraction)
  return input_img, output_img

# %% [markdown]
# The following cell provides code for parsing the contents of the TensorFlow Record files. In addition to loading the data, it also offers functions for various preprocessing operations, such as clipping, rescaling, or normalizing the data.

# %%
"""Dataset reader for Earth Engine data."""

def _get_base_key(key: Text) -> Text:
  """Extracts the base key from the provided key.

  Earth Engine exports TFRecords containing each data variable with its
  corresponding variable name. In the case of time sequences, the name of the
  data variable is of the form 'variable_1', 'variable_2', ..., 'variable_n',
  where 'variable' is the name of the variable, and n the number of elements
  in the time sequence. Extracting the base key ensures that each step of the
  time sequence goes through the same normalization steps.
  The base key obeys the following naming pattern: '([a-zA-Z]+)'
  For instance, for an input key 'variable_1', this function returns 'variable'.
  For an input key 'variable', this function simply returns 'variable'.

  Args:
    key: Input key.

  Returns:
    The corresponding base key.

  Raises:
    ValueError when `key` does not match the expected pattern.
  """
  match = re.match(r'([a-zA-Z]+)', key)
  if match:
    return match.group(1)
  raise ValueError(
      'The provided key does not match the expected pattern: {}'.format(key))


def _clip_and_rescale(inputs: tf.Tensor, key: Text) -> tf.Tensor:
  """Clips and rescales inputs with the stats corresponding to `key`.

  Args:
    inputs: Inputs to clip and rescale.
    key: Key describing the inputs.

  Returns:
    Clipped and rescaled input.

  Raises:
    ValueError if there are no data statistics available for `key`.
  """
  base_key = _get_base_key(key)
  if base_key not in DATA_STATS:
    raise ValueError(
        'No data statistics available for the requested key: {}.'.format(key))
  min_val, max_val, _, _ = DATA_STATS[base_key]
  inputs = tf.clip_by_value(inputs, min_val, max_val)
  return tf.math.divide_no_nan((inputs - min_val), (max_val - min_val))


def _clip_and_normalize(inputs: tf.Tensor, key: Text) -> tf.Tensor:
  """Clips and normalizes inputs with the stats corresponding to `key`.

  Args:
    inputs: Inputs to clip and normalize.
    key: Key describing the inputs.

  Returns:
    Clipped and normalized input.

  Raises:
    ValueError if there are no data statistics available for `key`.
  """
  base_key = _get_base_key(key)
  if base_key not in DATA_STATS:
    raise ValueError(
        'No data statistics available for the requested key: {}.'.format(key))
  min_val, max_val, mean, std = DATA_STATS[base_key]
  inputs = tf.clip_by_value(inputs, min_val, max_val)
  inputs = inputs - mean
  return tf.math.divide_no_nan(inputs, std)

def _get_features_dict(
    sample_size: int,
    features: List[Text],
) -> Dict[Text, tf.io.FixedLenFeature]:
  """Creates a features dictionary for TensorFlow IO.

  Args:
    sample_size: Size of the input tiles (square).
    features: List of feature names.

  Returns:
    A features dictionary for TensorFlow IO.
  """
  sample_shape = [sample_size, sample_size]
  features = set(features)
  columns = [
      tf.io.FixedLenFeature(shape=sample_shape, dtype=tf.float32)
      for _ in features
  ]
  return dict(zip(features, columns))


def _parse_fn(
    example_proto: tf.train.Example, data_size: int, sample_size: int,
    num_in_channels: int, clip_and_normalize: bool,
    clip_and_rescale: bool, random_crop: bool, center_crop: bool,
) -> Tuple[tf.Tensor, tf.Tensor]:
  """Reads a serialized example.

  Args:
    example_proto: A TensorFlow example protobuf.
    data_size: Size of tiles (square) as read from input files.
    sample_size: Size the tiles (square) when input into the model.
    num_in_channels: Number of input channels.
    clip_and_normalize: True if the data should be clipped and normalized.
    clip_and_rescale: True if the data should be clipped and rescaled.
    random_crop: True if the data should be randomly cropped.
    center_crop: True if the data should be cropped in the center.

  Returns:
    (input_img, output_img) tuple of inputs and outputs to the ML model.
  """
  if (random_crop and center_crop):
    raise ValueError('Cannot have both random_crop and center_crop be True')
  input_features, output_features = INPUT_FEATURES, OUTPUT_FEATURES
  feature_names = input_features + output_features
  features_dict = _get_features_dict(data_size, feature_names)
  features = tf.io.parse_single_example(example_proto, features_dict)

  if clip_and_normalize:
    inputs_list = [
        _clip_and_normalize(features.get(key), key) for key in input_features
    ]
  elif clip_and_rescale:
    inputs_list = [
        _clip_and_rescale(features.get(key), key) for key in input_features
    ]
  else:
    inputs_list = [features.get(key) for key in input_features]
  
  inputs_stacked = tf.stack(inputs_list, axis=0)
  input_img = tf.transpose(inputs_stacked, [1, 2, 0])

  outputs_list = [features.get(key) for key in output_features]
  assert outputs_list, 'outputs_list should not be empty'
  outputs_stacked = tf.stack(outputs_list, axis=0)

  outputs_stacked_shape = outputs_stacked.get_shape().as_list()
  assert len(outputs_stacked.shape) == 3, ('outputs_stacked should be rank 3'
                                            'but dimensions of outputs_stacked'
                                            f' are {outputs_stacked_shape}')
  output_img = tf.transpose(outputs_stacked, [1, 2, 0])

  if random_crop:
    input_img, output_img = random_crop_input_and_output_images(
        input_img, output_img, sample_size, num_in_channels, 1)
  if center_crop:
    input_img, output_img = center_crop_input_and_output_images(
        input_img, output_img, sample_size)
  return input_img, output_img


def get_dataset(file_pattern: Text, data_size: int, sample_size: int,
                batch_size: int, num_in_channels: int, compression_type: Text,
                clip_and_normalize: bool, clip_and_rescale: bool,
                random_crop: bool, center_crop: bool) -> tf.data.Dataset:
  """Gets the dataset from the file pattern.

  Args:
    file_pattern: Input file pattern.
    data_size: Size of tiles (square) as read from input files.
    sample_size: Size the tiles (square) when input into the model.
    batch_size: Batch size.
    num_in_channels: Number of input channels.
    compression_type: Type of compression used for the input files.
    clip_and_normalize: True if the data should be clipped and normalized, False
      otherwise.
    clip_and_rescale: True if the data should be clipped and rescaled, False
      otherwise.
    random_crop: True if the data should be randomly cropped.
    center_crop: True if the data shoulde be cropped in the center.

  Returns:
    A TensorFlow dataset loaded from the input file pattern, with features
    described in the constants, and with the shapes determined from the input
    parameters to this function.
  """
  if (clip_and_normalize and clip_and_rescale):
    raise ValueError('Cannot have both normalize and rescale.')
  dataset = tf.data.Dataset.list_files(file_pattern)
  dataset = dataset.interleave(
      lambda x: tf.data.TFRecordDataset(x, compression_type=compression_type),
      num_parallel_calls=tf.data.experimental.AUTOTUNE)
  dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
  dataset = dataset.map(
      lambda x: _parse_fn(  # pylint: disable=g-long-lambda
          x, data_size, sample_size, num_in_channels, clip_and_normalize,
          clip_and_rescale, random_crop, center_crop),
      num_parallel_calls=tf.data.experimental.AUTOTUNE)
  dataset = dataset.batch(batch_size)
  dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
  return dataset

# %% [markdown]
# Load the dataset.
#
# The data are stored as 64x64 km regions. For each data sample, we extract a random 32x32 km region. In the following function call, we do not clip, rescale or normalize the data.

# %%
dataset = get_dataset(
      file_pattern,
      data_size=64,
      sample_size=32,
      batch_size=100,
      num_in_channels=12,
      compression_type=None,
      clip_and_normalize=False,
      clip_and_rescale=False,
      random_crop=True,
      center_crop=False)
# Out:
# 2022-10-08 12:08:11.119754: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-08 12:08:11.268954: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-08 12:08:11.269722: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-08 12:08:11.272220: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-08 12:08:11.273374: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-08 12:08:11.274107: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-08 12:08:11.274763: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-08 12:08:13.344468: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-08 12:08:13.345349: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-08 12:08:13.346029: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-08 12:08:13.346635: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15403 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0

# %% [markdown]
# TF Datasets are loaded lazily, so materialize the first batch of inputs and labels.

# %%
inputs, labels = next(iter(dataset))
# Out:
# 2022-10-08 12:08:14.194148: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)

# %% [markdown]
# # Plotting function

# %% [markdown]
# Let's plot the data!
#
# First we define the names for each of our variables.

# %%
TITLES = [
  'Elevation',
  'Wind\ndirection',
  'Wind\nvelocity',
  'Min\ntemp',
  'Max\ntemp',
  'Humidity',
  'Precip',
  'Drought',
  'Vegetation',
  'Population\ndensity',
  'Energy\nrelease\ncomponent',
  'Previous\nfire\nmask',
  'Fire\nmask'
]

# %% [markdown]
# Define some helper variables for the plot.

# %%
# Number of rows of data samples to plot
n_rows = 5 
# Number of data variables
n_features = inputs.shape[3]
# Variables for controllong the color map for the fire masks
CMAP = colors.ListedColormap(['black', 'silver', 'orangered'])
BOUNDS = [-1, -0.1, 0.001, 1]
NORM = colors.BoundaryNorm(BOUNDS, CMAP.N)

# %%
fig = plt.figure(figsize=(15,6.5))

for i in range(n_rows):
  for j in range(n_features + 1):
    plt.subplot(n_rows, n_features + 1, i * (n_features + 1) + j + 1)
    if i == 0:
      plt.title(TITLES[j], fontsize=13)
    if j < n_features - 1:
      plt.imshow(inputs[i, :, :, j], cmap='viridis')
    if j == n_features - 1:
      plt.imshow(inputs[i, :, :, -1], cmap=CMAP, norm=NORM)
    if j == n_features:
      plt.imshow(labels[i, :, :, 0], cmap=CMAP, norm=NORM) 
    plt.axis('off')
plt.tight_layout()

# %% [markdown]
# # **Creating the model**

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import *

def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

def Unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
input_img = Input((32, 32, 12), name='img')
model = Unet(input_img, n_filters=16, dropout=0.05, batchnorm=True)
metrics = ["accuracy", 
        tf.keras.metrics.AUC(), 
        tf.keras.metrics.SensitivityAtSpecificity(0.5), 
        tf.keras.metrics.SpecificityAtSensitivity(0.5)]

model.compile(optimizer=Adam(), loss="binary_crossentropy", metrics=metrics)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 32, 32, 12)] 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 32, 32, 16)   1744        img[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 32, 32, 16)   64          conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 32, 32, 16)   0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 16, 16, 16)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 16, 16, 16)   0           max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 16, 16, 32)   4640        dropout[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 16, 16, 32)   128         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 16, 16, 32)   0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 8, 8, 32)     0           activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 8, 8, 32)     0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 8, 8, 64)     18496       dropout_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 8, 8, 64)     256         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 8, 8, 64)     0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 4, 4, 64)     0           activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 4, 4, 64)     0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 4, 4, 128)    73856       dropout_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 4, 4, 128)    512         conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 4, 4, 128)    0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 2, 2, 128)    0           activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 2, 2, 128)    0           max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 2, 2, 256)    295168      dropout_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 2, 2, 256)    1024        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 2, 2, 256)    0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 4, 4, 128)    295040      activation_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 4, 4, 256)    0           conv2d_transpose[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 4, 4, 256)    0           concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 4, 4, 128)    295040      dropout_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 4, 4, 128)    512         conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 4, 4, 128)    0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 8, 8, 64)     73792       activation_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 8, 8, 128)    0           conv2d_transpose_1[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 8, 8, 128)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 8, 8, 64)     73792       dropout_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 8, 8, 64)     256         conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 8, 8, 64)     0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 16, 16, 32)   18464       activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 16, 16, 64)   0           conv2d_transpose_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 16, 16, 64)   0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 16, 16, 32)   18464       dropout_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 16, 16, 32)   128         conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 16, 16, 32)   0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 32, 32, 16)   4624        activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 32)   0           conv2d_transpose_3[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 32, 32, 32)   0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 32, 32, 16)   4624        dropout_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 32, 32, 16)   64          conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 32, 32, 16)   0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 32, 32, 1)    17          activation_17[0][0]
# ==================================================================================================
# Total params: 1,180,705
# Trainable params: 1,179,233
# Non-trainable params: 1,472
# __________________________________________________________________________________________________

# %%
model.fit(dataset, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 150/150 - 6s - loss: -6.6300e-01 - accuracy: 0.9527 - auc: 0.5364 - sensitivity_at_specificity: 0.4749 - specificity_at_sensitivity: 0.0237
# Epoch 2/100
# 150/150 - 6s - loss: -8.0143e-01 - accuracy: 0.9530 - auc: 0.5310 - sensitivity_at_specificity: 0.4554 - specificity_at_sensitivity: 0.0294
# Epoch 3/100
# 150/150 - 6s - loss: -9.2663e-01 - accuracy: 0.9531 - auc: 0.5379 - sensitivity_at_specificity: 0.4118 - specificity_at_sensitivity: 0.0382
# Epoch 4/100
# 150/150 - 7s - loss: -1.0647e+00 - accuracy: 0.9529 - auc: 0.5445 - sensitivity_at_specificity: 0.4123 - specificity_at_sensitivity: 0.0504
# Epoch 5/100
# 150/150 - 6s - loss: -1.2408e+00 - accuracy: 0.9532 - auc: 0.5343 - sensitivity_at_specificity: 0.3868 - specificity_at_sensitivity: 0.0618
# Epoch 6/100
# Epoch 7/100
# 150/150 - 6s - loss: -1.5878e+00 - accuracy: 0.9530 - auc: 0.5448 - sensitivity_at_specificity: 0.3752 - specificity_at_sensitivity: 0.0835
# Epoch 8/100
# 150/150 - 6s - loss: -1.7443e+00 - accuracy: 0.9533 - auc: 0.5454 - sensitivity_at_specificity: 0.3647 - specificity_at_sensitivity: 0.0859
# Epoch 9/100
# 150/150 - 7s - loss: -1.8751e+00 - accuracy: 0.9531 - auc: 0.5437 - sensitivity_at_specificity: 0.3537 - specificity_at_sensitivity: 0.0933
# Epoch 10/100
# 150/150 - 6s - loss: -2.1859e+00 - accuracy: 0.9533 - auc: 0.5404 - sensitivity_at_specificity: 0.3343 - specificity_at_sensitivity: 0.1001
# Epoch 11/100
# 150/150 - 6s - loss: -2.2714e+00 - accuracy: 0.9531 - auc: 0.5380 - sensitivity_at_specificity: 0.3637 - specificity_at_sensitivity: 0.1199
# Epoch 12/100
# 150/150 - 6s - loss: -2.6283e+00 - accuracy: 0.9530 - auc: 0.5382 - sensitivity_at_specificity: 0.3155 - specificity_at_sensitivity: 0.1191
# Epoch 13/100
# 150/150 - 6s - loss: -2.7948e+00 - accuracy: 0.9532 - auc: 0.5417 - sensitivity_at_specificity: 0.3497 - specificity_at_sensitivity: 0.1374
# Epoch 14/100
# 150/150 - 6s - loss: -2.9015e+00 - accuracy: 0.9535 - auc: 0.5426 - sensitivity_at_specificity: 0.3439 - specificity_at_sensitivity: 0.1493
# Epoch 15/100
# 150/150 - 6s - loss: -3.0929e+00 - accuracy: 0.9534 - auc: 0.5526 - sensitivity_at_specificity: 0.3791 - specificity_at_sensitivity: 0.1638
# Epoch 16/100
# 150/150 - 6s - loss: -3.3790e+00 - accuracy: 0.9535 - auc: 0.5443 - sensitivity_at_specificity: 0.3586 - specificity_at_sensitivity: 0.1763
# Epoch 17/100
# 150/150 - 6s - loss: -3.6271e+00 - accuracy: 0.9533 - auc: 0.5410 - sensitivity_at_specificity: 0.3501 - specificity_at_sensitivity: 0.1929
# Epoch 18/100
# 150/150 - 6s - loss: -4.2148e+00 - accuracy: 0.9530 - auc: 0.5428 - sensitivity_at_specificity: 0.3246 - specificity_at_sensitivity: 0.1915
# Epoch 19/100
# 150/150 - 6s - loss: -4.2268e+00 - accuracy: 0.9531 - auc: 0.5448 - sensitivity_at_specificity: 0.3359 - specificity_at_sensitivity: 0.2065
# Epoch 20/100
# 150/150 - 6s - loss: -4.5300e+00 - accuracy: 0.9532 - auc: 0.5418 - sensitivity_at_specificity: 0.3349 - specificity_at_sensitivity: 0.2129
# Epoch 21/100
# 150/150 - 6s - loss: -4.8319e+00 - accuracy: 0.9530 - auc: 0.5440 - sensitivity_at_specificity: 0.3421 - specificity_at_sensitivity: 0.2380
# Epoch 22/100
# 150/150 - 6s - loss: -5.0567e+00 - accuracy: 0.9536 - auc: 0.5442 - sensitivity_at_specificity: 0.3572 - specificity_at_sensitivity: 0.2530
# Epoch 23/100
# 150/150 - 6s - loss: -5.3494e+00 - accuracy: 0.9533 - auc: 0.5403 - sensitivity_at_specificity: 0.3481 - specificity_at_sensitivity: 0.2551
# Epoch 24/100
# 150/150 - 6s - loss: -5.4886e+00 - accuracy: 0.9533 - auc: 0.5457 - sensitivity_at_specificity: 0.3350 - specificity_at_sensitivity: 0.2707
# Epoch 25/100
# 150/150 - 6s - loss: -6.0890e+00 - accuracy: 0.9532 - auc: 0.5443 - sensitivity_at_specificity: 0.3308 - specificity_at_sensitivity: 0.2889
# Epoch 26/100
# 150/150 - 6s - loss: -6.7102e+00 - accuracy: 0.9530 - auc: 0.5423 - sensitivity_at_specificity: 0.3173 - specificity_at_sensitivity: 0.2880
# Epoch 27/100
# 150/150 - 6s - loss: -6.7423e+00 - accuracy: 0.9529 - auc: 0.5478 - sensitivity_at_specificity: 0.3349 - specificity_at_sensitivity: 0.2949
# Epoch 28/100
# 150/150 - 6s - loss: -7.0553e+00 - accuracy: 0.9531 - auc: 0.5485 - sensitivity_at_specificity: 0.3452 - specificity_at_sensitivity: 0.3082
# Epoch 29/100
# 150/150 - 6s - loss: -7.7256e+00 - accuracy: 0.9532 - auc: 0.5406 - sensitivity_at_specificity: 0.3206 - specificity_at_sensitivity: 0.3195
# Epoch 30/100
# 150/150 - 6s - loss: -8.1244e+00 - accuracy: 0.9528 - auc: 0.5490 - sensitivity_at_specificity: 0.3310 - specificity_at_sensitivity: 0.3330
# Epoch 31/100
# 150/150 - 6s - loss: -8.0913e+00 - accuracy: 0.9532 - auc: 0.5440 - sensitivity_at_specificity: 0.3451 - specificity_at_sensitivity: 0.3313
# Epoch 32/100
# 150/150 - 6s - loss: -8.5937e+00 - accuracy: 0.9534 - auc: 0.5498 - sensitivity_at_specificity: 0.3490 - specificity_at_sensitivity: 0.3413
# Epoch 33/100
# 150/150 - 6s - loss: -8.9723e+00 - accuracy: 0.9536 - auc: 0.5487 - sensitivity_at_specificity: 0.3139 - specificity_at_sensitivity: 0.3672
# Epoch 34/100
# 150/150 - 6s - loss: -9.9105e+00 - accuracy: 0.9534 - auc: 0.5398 - sensitivity_at_specificity: 0.3361 - specificity_at_sensitivity: 0.3665
# Epoch 35/100
# 150/150 - 6s - loss: -9.2918e+00 - accuracy: 0.9537 - auc: 0.5338 - sensitivity_at_specificity: 0.3104 - specificity_at_sensitivity: 0.4010
# Epoch 36/100
# 150/150 - 7s - loss: -1.0334e+01 - accuracy: 0.9534 - auc: 0.5403 - sensitivity_at_specificity: 0.3255 - specificity_at_sensitivity: 0.3919
# Epoch 37/100
# 150/150 - 6s - loss: -1.0527e+01 - accuracy: 0.9533 - auc: 0.5445 - sensitivity_at_specificity: 0.3177 - specificity_at_sensitivity: 0.4000
# Epoch 38/100
# 150/150 - 6s - loss: -1.1306e+01 - accuracy: 0.9529 - auc: 0.5442 - sensitivity_at_specificity: 0.3247 - specificity_at_sensitivity: 0.4133
# Epoch 39/100
# 150/150 - 7s - loss: -1.1216e+01 - accuracy: 0.9542 - auc: 0.5478 - sensitivity_at_specificity: 0.3250 - specificity_at_sensitivity: 0.4285
# Epoch 40/100
# 150/150 - 6s - loss: -1.1820e+01 - accuracy: 0.9532 - auc: 0.5416 - sensitivity_at_specificity: 0.3510 - specificity_at_sensitivity: 0.4153
# Epoch 41/100
# 150/150 - 6s - loss: -1.2969e+01 - accuracy: 0.9536 - auc: 0.5506 - sensitivity_at_specificity: 0.3319 - specificity_at_sensitivity: 0.4181
# Epoch 42/100
# 150/150 - 7s - loss: -1.3309e+01 - accuracy: 0.9536 - auc: 0.5425 - sensitivity_at_specificity: 0.3143 - specificity_at_sensitivity: 0.4384
# Epoch 43/100
# 150/150 - 6s - loss: -1.3735e+01 - accuracy: 0.9531 - auc: 0.5457 - sensitivity_at_specificity: 0.3318 - specificity_at_sensitivity: 0.4478
# Epoch 44/100
# 150/150 - 6s - loss: -1.3905e+01 - accuracy: 0.9534 - auc: 0.5387 - sensitivity_at_specificity: 0.3430 - specificity_at_sensitivity: 0.4627
# Epoch 45/100
# 150/150 - 6s - loss: -1.4740e+01 - accuracy: 0.9532 - auc: 0.5416 - sensitivity_at_specificity: 0.3385 - specificity_at_sensitivity: 0.4723
# Epoch 46/100
# 150/150 - 6s - loss: -1.5340e+01 - accuracy: 0.9534 - auc: 0.5366 - sensitivity_at_specificity: 0.3151 - specificity_at_sensitivity: 0.4608
# Epoch 47/100
# 150/150 - 6s - loss: -1.5415e+01 - accuracy: 0.9534 - auc: 0.5389 - sensitivity_at_specificity: 0.3381 - specificity_at_sensitivity: 0.4645
# Epoch 48/100
# 150/150 - 6s - loss: -1.6187e+01 - accuracy: 0.9533 - auc: 0.5401 - sensitivity_at_specificity: 0.3235 - specificity_at_sensitivity: 0.4876
# Epoch 49/100
# 150/150 - 6s - loss: -1.7828e+01 - accuracy: 0.9532 - auc: 0.5439 - sensitivity_at_specificity: 0.3363 - specificity_at_sensitivity: 0.4821
# Epoch 50/100
# 150/150 - 6s - loss: -1.7171e+01 - accuracy: 0.9534 - auc: 0.5362 - sensitivity_at_specificity: 0.3185 - specificity_at_sensitivity: 0.4936
# Epoch 51/100
# 150/150 - 6s - loss: -1.8254e+01 - accuracy: 0.9528 - auc: 0.5430 - sensitivity_at_specificity: 0.3131 - specificity_at_sensitivity: 0.4948
# Epoch 52/100
# 150/150 - 6s - loss: -1.8819e+01 - accuracy: 0.9533 - auc: 0.5436 - sensitivity_at_specificity: 0.5208 - specificity_at_sensitivity: 0.5094
# Epoch 53/100
# 150/150 - 6s - loss: -2.0155e+01 - accuracy: 0.9534 - auc: 0.5393 - sensitivity_at_specificity: 0.5115 - specificity_at_sensitivity: 0.5102
# Epoch 54/100
# 150/150 - 6s - loss: -2.0339e+01 - accuracy: 0.9531 - auc: 0.5393 - sensitivity_at_specificity: 0.5079 - specificity_at_sensitivity: 0.5091
# Epoch 55/100
# 150/150 - 6s - loss: -2.0339e+01 - accuracy: 0.9534 - auc: 0.5403 - sensitivity_at_specificity: 0.5037 - specificity_at_sensitivity: 0.5262
# Epoch 56/100
# 150/150 - 6s - loss: -2.0595e+01 - accuracy: 0.9531 - auc: 0.5390 - sensitivity_at_specificity: 0.5097 - specificity_at_sensitivity: 0.5143
# Epoch 57/100
# 150/150 - 6s - loss: -2.2368e+01 - accuracy: 0.9529 - auc: 0.5409 - sensitivity_at_specificity: 0.4943 - specificity_at_sensitivity: 0.0000e+00
# Epoch 58/100
# 150/150 - 6s - loss: -2.3230e+01 - accuracy: 0.9529 - auc: 0.5381 - sensitivity_at_specificity: 0.4981 - specificity_at_sensitivity: 0.0000e+00
# Epoch 59/100
# 150/150 - 6s - loss: -2.2960e+01 - accuracy: 0.9534 - auc: 0.5441 - sensitivity_at_specificity: 0.4924 - specificity_at_sensitivity: 0.0000e+00
# Epoch 60/100
# 150/150 - 6s - loss: -2.3321e+01 - accuracy: 0.9534 - auc: 0.5411 - sensitivity_at_specificity: 0.5056 - specificity_at_sensitivity: 0.5283
# Epoch 61/100
# 150/150 - 6s - loss: -2.4021e+01 - accuracy: 0.9533 - auc: 0.5465 - sensitivity_at_specificity: 0.5125 - specificity_at_sensitivity: 0.5144
# Epoch 62/100
# 150/150 - 6s - loss: -2.4133e+01 - accuracy: 0.9539 - auc: 0.5401 - sensitivity_at_specificity: 0.4931 - specificity_at_sensitivity: 0.0000e+00
# Epoch 63/100
# 150/150 - 7s - loss: -2.6737e+01 - accuracy: 0.9527 - auc: 0.5462 - sensitivity_at_specificity: 0.4869 - specificity_at_sensitivity: 0.0000e+00
# Epoch 64/100
# 150/150 - 6s - loss: -2.7045e+01 - accuracy: 0.9533 - auc: 0.5411 - sensitivity_at_specificity: 0.4757 - specificity_at_sensitivity: 0.0000e+00
# Epoch 65/100
# 150/150 - 6s - loss: -2.7158e+01 - accuracy: 0.9532 - auc: 0.5452 - sensitivity_at_specificity: 0.4684 - specificity_at_sensitivity: 0.0000e+00
# Epoch 66/100
# 150/150 - 6s - loss: -2.8906e+01 - accuracy: 0.9534 - auc: 0.5462 - sensitivity_at_specificity: 0.4725 - specificity_at_sensitivity: 0.0000e+00
# Epoch 67/100
# 150/150 - 6s - loss: -3.0584e+01 - accuracy: 0.9530 - auc: 0.5428 - sensitivity_at_specificity: 0.4738 - specificity_at_sensitivity: 0.0000e+00
# Epoch 68/100
# 150/150 - 6s - loss: -2.9080e+01 - accuracy: 0.9531 - auc: 0.5451 - sensitivity_at_specificity: 0.4754 - specificity_at_sensitivity: 0.0000e+00
# Epoch 69/100
# 150/150 - 6s - loss: -3.0763e+01 - accuracy: 0.9534 - auc: 0.5426 - sensitivity_at_specificity: 0.4641 - specificity_at_sensitivity: 0.0000e+00
# Epoch 70/100
# 150/150 - 6s - loss: -3.1099e+01 - accuracy: 0.9538 - auc: 0.5434 - sensitivity_at_specificity: 0.4732 - specificity_at_sensitivity: 0.0000e+00
# Epoch 71/100
# 150/150 - 7s - loss: -3.3029e+01 - accuracy: 0.9538 - auc: 0.5395 - sensitivity_at_specificity: 0.4665 - specificity_at_sensitivity: 0.0000e+00
# Epoch 72/100
# 150/150 - 6s - loss: -3.3217e+01 - accuracy: 0.9529 - auc: 0.5431 - sensitivity_at_specificity: 0.4711 - specificity_at_sensitivity: 0.0000e+00
# Epoch 73/100
# 150/150 - 6s - loss: -3.3045e+01 - accuracy: 0.9534 - auc: 0.5462 - sensitivity_at_specificity: 0.4762 - specificity_at_sensitivity: 0.0000e+00
# Epoch 74/100
# 150/150 - 6s - loss: -3.6050e+01 - accuracy: 0.9532 - auc: 0.5454 - sensitivity_at_specificity: 0.4576 - specificity_at_sensitivity: 0.0000e+00
# Epoch 75/100
# 150/150 - 7s - loss: -3.5604e+01 - accuracy: 0.9531 - auc: 0.5410 - sensitivity_at_specificity: 0.4641 - specificity_at_sensitivity: 0.0000e+00
# Epoch 76/100
# 150/150 - 6s - loss: -3.6203e+01 - accuracy: 0.9532 - auc: 0.5417 - sensitivity_at_specificity: 0.4558 - specificity_at_sensitivity: 0.0000e+00
# Epoch 77/100
# 150/150 - 6s - loss: -3.7917e+01 - accuracy: 0.9535 - auc: 0.5498 - sensitivity_at_specificity: 0.4668 - specificity_at_sensitivity: 0.0000e+00
# Epoch 78/100
# 150/150 - 6s - loss: -3.7199e+01 - accuracy: 0.9532 - auc: 0.5512 - sensitivity_at_specificity: 0.4780 - specificity_at_sensitivity: 0.0000e+00
# Epoch 79/100
# 150/150 - 6s - loss: -3.9603e+01 - accuracy: 0.9529 - auc: 0.5458 - sensitivity_at_specificity: 0.4533 - specificity_at_sensitivity: 0.0000e+00
# Epoch 80/100
# 150/150 - 7s - loss: -3.9552e+01 - accuracy: 0.9534 - auc: 0.5502 - sensitivity_at_specificity: 0.4734 - specificity_at_sensitivity: 0.0000e+00
# Epoch 81/100
# 150/150 - 6s - loss: -4.1488e+01 - accuracy: 0.9535 - auc: 0.5379 - sensitivity_at_specificity: 0.4587 - specificity_at_sensitivity: 0.0000e+00
# Epoch 82/100
# 150/150 - 6s - loss: -4.2494e+01 - accuracy: 0.9533 - auc: 0.5401 - sensitivity_at_specificity: 0.4581 - specificity_at_sensitivity: 0.0000e+00
# Epoch 83/100
# 150/150 - 6s - loss: -4.3257e+01 - accuracy: 0.9530 - auc: 0.5453 - sensitivity_at_specificity: 0.4652 - specificity_at_sensitivity: 0.0000e+00
# Epoch 84/100
# 150/150 - 6s - loss: -4.3818e+01 - accuracy: 0.9529 - auc: 0.5460 - sensitivity_at_specificity: 0.4465 - specificity_at_sensitivity: 0.0000e+00
# Epoch 85/100
# 150/150 - 6s - loss: -4.4663e+01 - accuracy: 0.9531 - auc: 0.5471 - sensitivity_at_specificity: 0.4386 - specificity_at_sensitivity: 0.0000e+00
# Epoch 86/100
# 150/150 - 6s - loss: -4.7399e+01 - accuracy: 0.9530 - auc: 0.5448 - sensitivity_at_specificity: 0.4459 - specificity_at_sensitivity: 0.0000e+00
# Epoch 87/100
# 150/150 - 6s - loss: -4.8316e+01 - accuracy: 0.9532 - auc: 0.5497 - sensitivity_at_specificity: 0.4350 - specificity_at_sensitivity: 0.0000e+00
# Epoch 88/100
# 150/150 - 6s - loss: -4.9502e+01 - accuracy: 0.9528 - auc: 0.5403 - sensitivity_at_specificity: 0.4234 - specificity_at_sensitivity: 0.0000e+00
# Epoch 89/100
# 150/150 - 6s - loss: -4.9597e+01 - accuracy: 0.9534 - auc: 0.5444 - sensitivity_at_specificity: 0.4345 - specificity_at_sensitivity: 0.0000e+00
# Epoch 90/100
# 150/150 - 6s - loss: -4.9423e+01 - accuracy: 0.9535 - auc: 0.5442 - sensitivity_at_specificity: 0.4419 - specificity_at_sensitivity: 0.0000e+00
# Epoch 91/100
# 150/150 - 6s - loss: -5.0361e+01 - accuracy: 0.9536 - auc: 0.5484 - sensitivity_at_specificity: 0.4535 - specificity_at_sensitivity: 0.0000e+00
# Epoch 92/100
# 150/150 - 6s - loss: -5.0419e+01 - accuracy: 0.9538 - auc: 0.5464 - sensitivity_at_specificity: 0.4544 - specificity_at_sensitivity: 0.0000e+00
# Epoch 93/100
# 150/150 - 6s - loss: -5.4776e+01 - accuracy: 0.9535 - auc: 0.5474 - sensitivity_at_specificity: 0.4218 - specificity_at_sensitivity: 0.0000e+00
# Epoch 94/100
# 150/150 - 6s - loss: -5.5201e+01 - accuracy: 0.9535 - auc: 0.5448 - sensitivity_at_specificity: 0.4368 - specificity_at_sensitivity: 0.0000e+00
# Epoch 95/100
# 150/150 - 6s - loss: -5.4550e+01 - accuracy: 0.9532 - auc: 0.5479 - sensitivity_at_specificity: 0.4346 - specificity_at_sensitivity: 0.0000e+00
# Epoch 96/100
# 150/150 - 6s - loss: -5.5947e+01 - accuracy: 0.9536 - auc: 0.5483 - sensitivity_at_specificity: 0.4272 - specificity_at_sensitivity: 0.0000e+00
# Epoch 97/100
# 150/150 - 7s - loss: -6.1177e+01 - accuracy: 0.9531 - auc: 0.5472 - sensitivity_at_specificity: 0.4331 - specificity_at_sensitivity: 0.0000e+00
# Epoch 98/100
# 150/150 - 6s - loss: -5.8596e+01 - accuracy: 0.9535 - auc: 0.5464 - sensitivity_at_specificity: 0.4385 - specificity_at_sensitivity: 0.0000e+00
# Epoch 99/100
# 150/150 - 6s - loss: -6.2742e+01 - accuracy: 0.9528 - auc: 0.5510 - sensitivity_at_specificity: 0.4266 - specificity_at_sensitivity: 0.0000e+00
# Epoch 100/100
# 150/150 - 6s - loss: -6.5407e+01 - accuracy: 0.9527 - auc: 0.5432 - sensitivity_at_specificity: 0.4134 - specificity_at_sensitivity: 0.0000e+00

# %%
y_pred = model.predict(inputs)

# %%
kth = 78
plt.imshow(inputs[kth][:, :, 11], cmap=CMAP, norm=NORM)
plt.figure()
plt.imshow(y_pred[kth], cmap=CMAP, norm=NORM)

# %%
kth = 55
plt.imshow(inputs[kth][:, :, 11], cmap=CMAP, norm=NORM)
plt.figure()
plt.imshow(y_pred[kth], cmap=CMAP, norm=NORM)

# %%
model.save('saved_model/next_day_fire_spread_predict.h5')
